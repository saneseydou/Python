# %% [markdown]
# <a href="https://colab.research.google.com/github/saneseydou/Python/blob/master/check_point_math_op%C3%A9ration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create four basic mathematical functions: 'add', 'subtract', 'multiply', and 'divide' that take in two numbers and return the result of the operation.
# Create a dictionary 'operations' that assigns the functions to their corresponding operation symbols.
# Use the dictionary to retrieve the function that corresponds to the selected operation symbol and store it in a variable 'calculation_function'
# Use a for loop to print the available operation symbols.
# Create a while loop that will continue to run until the user chooses to end the current calculation.
# Print the equation and the result of the calculation.
# Ask the user if they would like to continue using the result as the first number for further calculations.
# If the user chooses to continue, update the 'num1' variable to the value of 'answer'.
# If the user chooses to start a new calculation, set the 'should_continue' variable to false and call the 'calculator' function to start a new calculation.



print("Merci de taper 1 pour additionner")          #Affichage d'accueil
print("Merci de taper 2 pour soustraire")
print("Merci de taper 3 pour multiplier")
print("Merci de taper 4 pour diviser")
print("Merci de taper 5 si décider de quitter")

def math_cal():

  while True:
    i=int(input("taper le numéro de votre choix: 1 ou 2 ou 3 ou 4 ou 5"))    # Inside the while loop, prompt the user to select an operation symbol.
    if i==5:
      print("Merci Aurevoir !!!")
      break
    elif i in [1,2,3,4] :
      val_1 = int(input("saisir votre première valeur"))    # Create a function 'calculator' that prompts the user to input the first number.
      val_2 = int(input("saisir votre seconde valeur"))     # Prompt the user to input the second number.

      if i== 1 :
        somme = (val_1 + val_2)    # Perform the calculation by calling the 'calculation_function' on the two input numbers and store the result in a variable 'answer'.
        print(f" le résultat de la somme entre val_1 et val_2 est : {somme}")
      elif i==2 :
        if val_1 > val_2:
          différence = (val_1 - val_2)
          print(f" le resultat de la différence entre entre val_1 et val_2 est : {différence}")
        else :
          différence =(val_2 - val_1)
          print(f" le resultat de la différence entre entre val_1 et val_2 est : {différence}")
      elif i==3 :
        multiplication= (val_1*val_2)
        print(f"le resultat de la multiplication entre val_1 et val_2 est : {multiplication}")
      elif i==4 :
        division=(val_1/val_2)
        print(f"le resultat division entre val_1 et val_2 est : {division}")
      else :
        print("vérifier vos valeurs saisis")
math_cal()
# Out:
# Merci de taper 1 pour additionner
# Merci de taper 2 pour soustraire
# Merci de taper 3 pour multiplier
# Merci de taper 4 pour diviser
# Merci de taper 5 si décider de quitter
# taper le numéro de votre choix: 1 ou 2 ou 3 ou 4 ou 54
# saisir votre première valeur5
# saisir votre seconde valeur245
# le resultat division entre val_1 et val_2 est : 0.02040816326530612
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-2d0302d138fb> in <cell line: 48>()
#      46       else :
#      47         print("vérifier vos valeurs saisis")
# ---> 48 math_cal()
#      49
#      50
#
# <ipython-input-20-2d0302d138fb> in math_cal()
#      20
#      21   while True:
# ---> 22     i=int(input("taper le numéro de votre choix: 1 ou 2 ou 3 ou 4 ou 5"))    # Inside the while loop, prompt the user to select an operation symbol.
#      23     if i==5:
# ...
