# %% [markdown]
# <a href="https://colab.research.google.com/github/saneseydou/Python/blob/master/checkpoint_commad_pizza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total_commande=0    #entier
prix_L=0       #entier
prix_Y=0       #entier
prix_N=0       #entier

L= input("quelle taille pizza vous convient (Grande, Moyenne, Petite), Please !")
if L.lower()== 'grande' :
  prix_L=13
elif L.lower()== 'moyenne':
  prix_L=11
elif L.lower()== 'petite':
  prix_L=7
else : print("taille pizza non valide, sorry \n la taille de votre pizza (Grande, Moyenne, Petite)? ")
Y= input("souhaitez vous avoir du pepperoni sur votre pizza ? OUI/NON ")
if Y.lower()== 'oui' :
  prix_Y=3
else: prix_Y=0
N= input("souhaitez vous avoir du fromage sur votre pizza ?OUI/NON ")
if N.lower()=='oui' :
  prix_N=1
else: prix_N= 0

total_commande= prix_L + prix_Y + prix_N
print(f'sizer: {L}')
print(f'add_pepperoni : {Y}')
print(f"extrat_cheese : {N}")
print(f"votre facture vaut : {total_commande} $")
# Out:
# quelle taille pizza vous convient (Grande, Moyenne, Petite), Please !GRande
# souhaitez vous avoir du pepperoni sur votre pizza ? OUI/NON Oui
# souhaitez vous avoir du fromage sur votre pizza ?OUI/NON Non
# sizer: GRande
# add_pepperoni : Oui
# extrat_cheese : Non
# votre facture vaut : 16 $

# %%
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']
