# %% [markdown]
# <a href="https://colab.research.google.com/github/saneseydou/Python/blob/master/check_point_shoopping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
shopping_list =input("mettez votre liste de produit séparer par une virgule ").lower().split(",") #.lower() nous permet de convertir en minuscule /.split(",") nous permet de créer une liste avec juste une séparation de caractère par une virgule
while True:
  print("Hello ! taper 1 pour ajouter un article")
  print("Hello ! taper 2 pour supprimer un article  ")
  print("Hello ! taper 3 pour afficher votre liste de commande ")
  print("TAPEZ 4 pour quitter ")


  item = input("taper le numéro choix ")

  if int(item) == 1:
    nombre=len(shopping_list)
    if nombre<=5:
      add_item = input("ajouter un article")                            #au client d'ajouter ces articles
      shopping_list.append(add_item)                                    #Ajout d'article
    else :
      print("vous avez atteint la limite de commande")
  elif int(item)==2 :
    del_item = input("choisir un article à supprimer")                #au client de retirer un articles de sa liste
    shopping_list.remove(del_item.lower())                            #suppression d'article

  elif int(item)==3 :
    print(shopping_list)                                              #attention de printer avec de quote sur votre liste
    for i in shopping_list:
      print(i)
  elif int(item)==4:
    print("Merci pour votre commande ")
    break                                                             #quiter la boucle pour finir la commande
  else :
    print("choix invalide")                                           #pour tout erreur de saisi
# Out:
# mettez votre liste de produit séparer par une virgule velo,table,sel,crayon,bic,stylo,bec
# Hello ! taper 1 pour ajouter un article
# Hello ! taper 2 pour supprimer un article
# Hello ! taper 3 pour afficher votre liste de commande
# TAPEZ 4 pour quitter
# taper le numéro choix 1
# vous avez atteint la limite de commande
# Hello ! taper 1 pour ajouter un article
# Hello ! taper 2 pour supprimer un article
# Hello ! taper 3 pour afficher votre liste de commande
# TAPEZ 4 pour quitter
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-25224b33e370> in <cell line: 2>()
#       7
#       8
# ----> 9   item = input("taper le numéro choix ")
#      10
#      11   if int(item) == 1:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %%
B=input("mettez votre liste de produit séparer par une virgule ").split(",")
print(B)
# Out:
# mettez votre liste de produit séparer par une virgule sac,cahier,bic,stylo,crayon
# ['sac', 'cahier', 'bic', 'stylo', 'crayon']
